# %%
import numpy as np

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Test").getOrCreate()

# %%
from thing import a_function

# %%
a_function()
# Out:
# I am a function
